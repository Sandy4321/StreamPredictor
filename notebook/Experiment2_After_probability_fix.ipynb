# %%
import sys
import nltk
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sys.path.insert(0,'../source/')

# %%
import Experiment
import StreamPredictor

# %%
Experiment.online_token_perplexity_trainer()
# Out:
# Starting online training with tokens and perplexity calculation
# The perplexity count constant is 6000
# The occasional step periods is 2000
# The not found raitio is0.9
# Feed strength gain is 1000000
# Loaded pop manager with  19050  patterns.
# Loaded PopManager.PopManager from  ../PatternStore/OnlineTokens.pb
# Iteration number 0
# Got book from  http://www.gutenberg.org/cache/epub/1711/pg1711.txt
# There are  3434  words in vocabulary.
# The first few words are  e,man,,,'',and,she,leered,in,my,direction
# Started training and calculating perplexity with  114355  words.
# Fixing incorrect first_child_parents
# Mismatch  Him: strength 1760889  and  Him.: strength 116902
# Mismatch  They: strength 8455721  and  Theyweretalking: strength 24000={ Theywere: talking}
# Mismatch  .: strength 414404104  and  .''``Idont: strength 86916={ .''``: Idont}
# Mismatch  .: strength 414404104  and  .Ihaveknown: strength 24000={ .Ihave: known}
# ...

# %% [markdown]
# Perplexity is very high, maybe need to use a bigger data set, or need to check code
